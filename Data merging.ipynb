# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from lightgbm import LGBMRegressor, plot_importance
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_log_error, mean_squared_error

import warnings
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas.util.testing as tm

# %%
train = pd.read_csv('train (1).csv')
test = pd.read_csv('test (1).csv')
meal_info = pd.read_csv('meal_info.csv')
fulfilment_center_info = pd.read_csv('fulfilment_center_info.csv')
sample_submission = pd.read_csv('sample_submission.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359484 entries, 0 to 359483
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     359484 non-null  int64
#  1   week                   359484 non-null  int64
#  2   center_id              359484 non-null  int64
#  3   meal_id                359484 non-null  int64
#  4   checkout_price         359484 non-null  float64
#  5   base_price             359484 non-null  float64
#  6   emailer_for_promotion  359484 non-null  int64
#  7   homepage_featured      359484 non-null  int64
#  8   num_orders             359484 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 24.7 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32573 entries, 0 to 32572
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     32573 non-null  int64
#  1   week                   32573 non-null  int64
#  2   center_id              32573 non-null  int64
#  3   meal_id                32573 non-null  int64
#  4   checkout_price         32573 non-null  float64
#  5   base_price             32573 non-null  float64
#  6   emailer_for_promotion  32573 non-null  int64
#  7   homepage_featured      32573 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 2.0 MB

# %%
train = pd.merge(train,fulfilment_center_info, on = 'center_id')
test = pd.merge(test,fulfilment_center_info, on = 'center_id')

train = pd.merge(train,meal_info, on = 'meal_id')
test = pd.merge(test,meal_info, on = 'meal_id')

# %%
train_test = pd.merge(train,test, how = "outer")

# %%
train_test.to_csv('D:\Series\train_test.csv')
